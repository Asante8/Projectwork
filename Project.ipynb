# %% [markdown]
# #### Name: Agyepong Kwesi Asante
# #### ID: 11038081
# #### Class : CPEN

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as mp

# %%
data = pd.read_csv('red_wine.csv')

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
data.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
data.tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1598 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1598.000000       1598.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740863          0.179092     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1595.000000          1598.000000           1599.000000  1598.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047117            10.459029             32.895324     0.001887
# ...

# %%
x=np.array(data['fixed acidity'])

# %%
x
# Out:
# array([7.4, 7.8, 7.8, ..., 6.3, 5.9, 6. ])

# %%
y=np.array(data['volatile acidity'])

# %%
y
# Out:
# array([0.7  , 0.88 , 0.76 , ..., 0.51 , 0.645, 0.31 ])

# %%
mp.plot(x,y)
mp.title('A graph of volatile acidity against fixed acidity')
mp.xlabel('fixed acidity')
mp.ylabel('volatile acidity')
# Out:
# Text(0, 0.5, 'volatile acidity')

# %%
a=np.array(data['citric acid'])
b=np.array(data['residual sugar'])

# %%
mp.plot(a,b)
mp.title('A graph of residual sugar against citric acid ')
mp.xlabel('citric acid')
mp.ylabel('residual sugar')
# Out:
# Text(0, 0.5, 'residual sugar')

# %%
mp.plot(data.density,data.pH)
mp.title('A graph of pH against density')
mp.xlabel('density')
mp.ylabel('pH')
# Out:
# Text(0, 0.5, 'pH')

# %%
mp.plot(data.alcohol,data.quality)
mp.title('A graph of alcohol against quality')
mp.xlabel('alcohol')
mp.ylabel('quality')
# Out:
# Text(0, 0.5, 'quality')

# %%
a=np.array(data['free sulfur dioxide'])
b=np.array(data['total sulfur dioxide'])
mp.plot(a,b)
mp.title('A graph of free sulfur dioxide against total sulfur dioxide ')
mp.xlabel('free sulfur dioxide')
mp.ylabel('total sulfur dioxide')
# Out:
# Text(0, 0.5, 'total sulfur dioxide')

# %%
data.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.255282     0.671371
# volatile acidity          -0.255282          1.000000    -0.552334
# citric acid                0.671371         -0.552334     1.000000
# residual sugar             0.114743          0.002075     0.143577
# chlorides                  0.093866          0.061107     0.203944
# free sulfur dioxide       -0.153762         -0.010496    -0.061884
# total sulfur dioxide      -0.112632          0.076881     0.035533
# density                    0.667799          0.021796     0.365370
# pH                        -0.683021          0.234801    -0.541904
# sulphates                  0.183213         -0.260870     0.312770
# alcohol                   -0.061062         -0.202097     0.109903
# quality                    0.124639         -0.390721     0.226166
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
mean_FA = data['fixed acidity'].mean()
mean_VA = data['volatile acidity'].mean()
mean_CA = data['citric acid'].mean()
mean_RS = data['residual sugar'].mean()
mean_CH = data['chlorides'].mean()
mean_FSD = data['free sulfur dioxide'].mean()
mean_TSD = data['total sulfur dioxide'].mean()
mean_D = data['density'].mean()
mean_pH = data['pH'].mean()
mean_S = data['sulphates'].mean()
mean_A = data['alcohol'].mean()
mean_Q = data['quality'].mean()
# Out:
# 5.635794743429287

# %%
print(f'The mean of fixed acidity is :{mean_FA}')
print(f'The mean of volatile acidity is :{mean_VA}')
print(f'The mean of citric acid is :{mean_CA}')
print(f'The mean of residual sugar is :{mean_RS}')
print(f'The mean of chlorides is :{mean_CH}')
print(f'The mean of free sulfur dioxide is :{mean_FSD}')
print(f'The mean of total sulfur dioxide is :{mean_TSD}')
print(f'The mean of density is :{mean_D}')
print(f'The mean of pH is :{mean_pH}')
print(f'The mean of sulphates is :{mean_S}')
print(f'The mean of alcohol is :{mean_A}')
print(f'The mean of quality is :{mean_Q}')
# Out:
# The mean of fixed acidity is :8.318335419274094
# The mean of volatile acidity is :0.527747183979975
# The mean of citric acid is :0.2709756097560976
# The mean of residual sugar is :2.53880550343965
# The mean of chlorides is :0.08747586206896552
# The mean of free sulfur dioxide is :15.867334167709638
# The mean of total sulfur dioxide is :46.46779237023139
# The mean of density is :0.996745519399249
# The mean of pH is :3.3111131957473416
# The mean of sulphates is :0.6581488430268917
# The mean of alcohol is :10.422983114446529
# The mean of quality is :5.635794743429287

# %%
mode_FA = data['fixed acidity'].mode()
mode_VA = data['volatile acidity'].mode()
mode_CA = data['citric acid'].mode()
mode_RS = data['residual sugar'].mode()
mode_CH = data['chlorides'].mode()
mode_FSD = data['free sulfur dioxide'].mode()
mode_TSD = data['total sulfur dioxide'].mode()
mode_D = data['density'].mode()
mode_pH = data['pH'].mode()
mode_S = data['sulphates'].mode()
mode_A = data['alcohol'].mode()
mode_Q = data['quality'].mode()
# Out:
# 0    0.9972
# Name: density, dtype: float64

# %%
print(f'The mode of fixed acidity is :{mode_FA}')
print(f'The mode of volatile acidity is :{mode_VA}')
print(f'The mode of citric acid is :{mode_CA}')
print(f'The mode of residual sugar is :{mode_RS}')
print(f'The mode of chlorides is :{mode_CH}')
print(f'The mode of free sulfur dioxide is :{mode_FSD}')
print(f'The mode of total sulfur dioxide is :{mode_TSD}')
print(f'The mode of density is :{mode_D}')
print(f'The mode of pH is :{mode_pH}')
print(f'The mode of sulphates is :{mode_S}')
print(f'The mode of alcohol is :{mode_A}')
print(f'The mode of quality is :{mode_Q}')
# Out:
# The mode of fixed acidity is :0    7.2
# Name: fixed acidity, dtype: float64
# The mode of volatile acidity is :0    0.6
# Name: volatile acidity, dtype: float64
# The mode of citric acid is :0    0.0
# Name: citric acid, dtype: float64
# The mode of residual sugar is :0    2.0
# Name: residual sugar, dtype: float64
# The mode of chlorides is :0    0.08
# Name: chlorides, dtype: float64
# The mode of free sulfur dioxide is :0    6.0
# Name: free sulfur dioxide, dtype: float64
# The mode of total sulfur dioxide is :0    28.0
# Name: total sulfur dioxide, dtype: float64
# The mode of density is :0    0.9972
# Name: density, dtype: float64
# The mode of pH is :0    3.3
# Name: pH, dtype: float64
# The mode of sulphates is :0    0.6
# Name: sulphates, dtype: float64
# The mode of alcohol is :0    9.5
# Name: alcohol, dtype: float64
# The mode of quality is :0    5.0
# Name: quality, dtype: float64

# %% [markdown]
# # Report

# %% [markdown]
# ### From the observation of the graphs, it will be difficult to tell or know the relationship between the components of the data set.So then I decided to use the correlation function to show or understand the relationship between the components
# ### From the correlation table,The relationship between the **Fixed acidity** and the **volatile acidity** is a negative correlation which means when the fixed acidity is increasing,volatile acidity decreases and vice versa
# ### * The table also shows that the relation between **alcohol** and **quality** is a positive correlation, which means the higher the alcohol level, the better the quality and vice versa
# ### * The table also shows that the relation between **citric acid** and **residual sugar** is a positive correlation, which means the higher the concentration of the citric acid, the larger the amount of residual sugar added and vice versa.
# ### * The table also shows that the relation between **density** and **pH** is a negative correlation which means when the density is increasing,pH  decreases and vice versa
# ### * The table also shows that the relation between **chlorides** and **sulphates** is a positive correlation, which means the higher the chlorides, the higher the sulphates and vice versa
# ### * The table also shows that the relation between **free sulfur dioxide** and **total sulfur dioxide** is a positive correlation, which means the higher the free sulphur dioxide level, the higher the amount of total sulfur dioxide and vice versa
